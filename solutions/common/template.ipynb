# %% [markdown]
# ## Setup

# %%
# Get raw advent-of-code data
from aocd.models import Puzzle

puzzle = Puzzle(year=2025, day=1)
input_data = puzzle.input_data
examples = puzzle.examples

# %%
# Optional: add parent directory to path to allow relative imports into Jupyter notebook
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %% [markdown]
# ## Part a

# %%
# Imports

# %%
# Functions

# %%
# Calculate solution
solution_part_a = 1

# %%
# Submit answer
puzzle.answer_a = solution_part_a

# %% [markdown]
# ## Part b

# %%
# Imports

# %%
# Functions

# %%
# Calculate solution
solution_part_b = 1

# %%
# Submit answer
puzzle.answer_b = solution_part_b
